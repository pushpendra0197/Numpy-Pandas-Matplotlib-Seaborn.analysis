# %% [markdown]
# #importing Libraries for data reading and manupuation or visualization

# %%
import numpy as np #numpy for performing arithmatic operation.
import pandas as pd # pandas for data reading or tranformation,manipulation
import matplotlib.pyplot as plt #for exploratory data visualization
# %matplotlib inline
import seaborn as sns #for exploratory data visualization

# %%
df=pd.read_excel(r"H:\power bi\power bi report on sample superstore\Analysis report on Sample Superstore.xlsx")

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# Attributes function in pandas

# %%
np.shape(df)
# Out:
# (9426, 24)

# %%
np.size(df)
# Out:
# 226224

# %%
np.ndim(df)
# Out:
# 2

# %% [markdown]
# checking is there any null values in column

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df["Product Base Margin"].fillna(df["Product Base Margin"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
df["Order Priority"].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
df["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
df["Order Priority"]=df["Order Priority"].replace('Critical ','Critical')

# %%
df["Order Priority"].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# pandas function

# %%
df.head(20)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    18606  Not Specified      0.01        2.88           0.50            2
# 1    20847           High      0.01        2.84           0.93            3
# 2    23086  Not Specified      0.03        6.68           6.15            3
# 3    23087  Not Specified      0.01        5.68           3.60            3
# 4    23088  Not Specified      0.00      205.99           2.50            3
# 5    23597         Medium      0.09       55.48          14.30            3
# 6    25549            Low      0.08      120.97          26.30            3
# 7    20228  Not Specified      0.02      500.98          26.00            5
# 8    19483            Low      0.08        6.48           6.81            5
# 9    24782           High      0.01       90.24           0.99            6
# 10   24563       Critical      0.07        6.48           6.60            6
# ...

# %%
df.tail(20)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 9406   22599       Critical      0.01      177.98           0.99         3398
# 9407   23074            Low      0.01      155.99           8.99         3398
# 9408   22194           High      0.00      160.98          35.02         3398
# 9409   26208  Not Specified      0.08       11.97           5.81         3399
# 9410   26073       Critical      0.05       59.78          10.29         3399
# 9411   26074       Critical      0.05        4.13           0.50         3399
# 9412   26075       Critical      0.01       30.98          17.08         3399
# 9413   24911         Medium      0.10        9.38           4.93         3400
# 9414   26042  Not Specified      0.09        8.46           3.62         3400
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9416   24933         Medium      0.01        7.64           5.83         3400
# ...

# %%
df.iloc[25:50] #to extract data from range
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 25   20925         Medium      0.01       35.94           6.66           15
# 26   18263         Medium      0.03        1.76           0.70           15
# 27   18554         Medium      0.04        5.98           5.20           15
# 28   22781            Low      0.00        7.59           4.00           15
# 29   23287            Low      0.07        4.13           6.89           15
# 30   26267           High      0.04        2.98           1.58           16
# 31   26268           High      0.05      115.99           2.50           16
# 32   26266           High      0.08       14.27           7.27           16
# 33   19359            Low      0.05        5.85           2.27           17
# 34   20459       Critical      0.05        7.77           9.23           17
# 35   23890           High      0.05       26.48           6.93           18
# ...

# %%
df.sample(10)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 4886   24469           High      0.03       95.43          19.99         1808
# 5452   18523           High      0.06       12.58           5.16         2015
# 6969   18653            Low      0.09        8.33           1.99         2550
# 5807   25622         Medium      0.03        7.10           6.05         2125
# 260     6245  Not Specified      0.06      115.99           8.99           94
# 1634   18490  Not Specified      0.06        5.38           5.24          618
# 6244   25263       Critical      0.04        7.84           4.71         2291
# 1825   19267            Low      0.03        3.25          49.00          691
# 9291   18348  Not Specified      0.01        2.84           5.44         3363
# 1170   26395       Critical      0.01       15.98           8.99          454
#
#             Customer Name    Ship Mode Customer Segment Product Category  ...  \
# ...

# %%
df.iloc[0]
# Out:
# Row ID                                18606
# Order Priority                Not Specified
# Discount                               0.01
# Unit Price                             2.88
# Shipping Cost                           0.5
# Customer ID                               2
# Customer Name               Janice Fletcher
# Ship Mode                       Regular Air
# Customer Segment                  Corporate
# Product Category            Office Supplies
# Product Sub-Category                 Labels
# Product Container                 Small Box
# Product Name                       Avery 49
# Product Base Margin                    0.36
# Region                              Central
# State or Province                  Illinois
# City                                Addison
# Postal Code                           60101
# Order Date              2012-05-28 00:00:00
# Ship Date               2012-05-30 00:00:00
# Profit                                 1.32
# ...

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
a=df["Customer_segment"].value_counts()
a
# Out:
# Customer_segment
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: count, dtype: int64

# %%
df.describe().round()
# Out:
#         Row ID  Discount  Unit Price  Shipping Cost  Customer ID  \
# count   9426.0    9426.0      9426.0         9426.0       9426.0
# mean   20241.0       0.0        88.0           13.0       1738.0
# min        2.0       0.0         1.0            0.0          2.0
# 25%    19330.0       0.0         6.0            3.0        898.0
# 50%    21686.0       0.0        21.0            6.0       1750.0
# 75%    24043.0       0.0        86.0           14.0       2579.0
# max    26399.0       0.0      6783.0          165.0       3403.0
# std     6102.0       0.0       282.0           17.0        979.0
#
#        Product Base Margin  Postal Code                     Order Date  \
# count               9426.0       9426.0                           9426
# mean                   1.0      52446.0  2012-03-05 18:33:59.465308672
# min                    0.0       1001.0            2010-01-01 00:00:00
# 25%                    0.0      29406.0            2011-03-07 06:00:00
# ...

# %%
c=df.rename(columns={"Customer Segment":"Customer_segment"},inplace=True)

# %%
sns.lineplot(d,x=d["year"],y=d["Profit"])
# Out:
# <Axes: xlabel='year', ylabel='Profit'>

# %%
sns.barplot(d,x=d["year"],y=d["Profit"])
# Out:
# <Axes: xlabel='year', ylabel='Profit'>

# %%
d=df.query('Customer_segment=="Corporate"')
d
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9414   26042  Not Specified      0.09        8.46           3.62         3400
# 9415   26043  Not Specified      0.06       30.98           6.50         3400
# 9416   24933         Medium      0.01        7.64           5.83         3400
# 9417   23413       Critical      0.07      115.79           1.99         3400
# 9418   23414       Critical      0.02       37.44           4.27         3400
#
# ...

# %%
t=df.query('Customer_segment=="Home Office"')
t
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 7      20228  Not Specified      0.02      500.98          26.00            5
# 8      19483            Low      0.08        6.48           6.81            5
# 9      24782           High      0.01       90.24           0.99            6
# 10     24563       Critical      0.07        6.48           6.60            6
# 11     24564       Critical      0.01        4.84           0.71            6
# ...      ...            ...       ...         ...            ...          ...
# 9351   23181       Critical      0.03      315.98          19.99         3380
# 9352   23182       Critical      0.09      276.20          24.49         3380
# 9353   23183       Critical      0.03       63.94          14.48         3380
# 9357   25841         Medium      0.02       28.53           1.49         3381
# 9359   25689       Critical      0.10        4.98           4.70         3381
#
# ...

# %%
sns.lineplot(t,x=t["year"],y=t["Profit"])
# Out:
# <Axes: xlabel='year', ylabel='Profit'>

# %%
sns.barplot(t,x=t["year"],y=t["Profit"])
# Out:
# <Axes: xlabel='year', ylabel='Profit'>

# %%
sns.barplot(a,x=a.values,y=a.index)
# Out:
# <Axes: ylabel='count'>

# %%
b=df["Quantity ordered new"].value_counts()
b
# Out:
# Quantity ordered new
# 1      628
# 9      499
# 5      499
# 11     498
# 12     498
#       ...
# 151      1
# 162      1
# 160      1
# 95       1
# 75       1
# Name: count, Length: 112, dtype: int64

# %%
c=df.sample(50)
d=sns.countplot(c,x=c["Quantity ordered new"])
plt.figure(figsize=(200,500))

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
w=sns.barplot(df,x=df["Customer Segment"],y=df["Profit"],hue=df["Product Category"])

# %%
df["year"]=pd.DatetimeIndex(df["Order Date"]).year

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
sns.barplot(df,x=df["Customer Segment"],y=df['Sales'],hue=df["Product Category"])
# Out:
# <Axes: xlabel='Customer Segment', ylabel='Sales'>

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
sns.barplot(df,x=df["year"],y=df["Sales"],hue=df["Product Category"])
# Out:
# <Axes: xlabel='year', ylabel='Sales'>

# %%
r=df.sample(10)
r
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 3084   18424       Critical      0.06       43.31          15.90         1180
# 3160   22131           High      0.05       52.40          16.11         1200
# 632    18849         Medium      0.02      146.05          80.20          247
# 4880   25866  Not Specified      0.03        6.48           7.91         1805
# 8940   23382           High      0.06       43.57          16.36         3233
# 7709   24408           High      0.04        7.64           5.83         2817
# 1248   23859           High      0.01       11.97           5.81          486
# 4741   21107            Low      0.10        1.76           0.70         1763
# 1267    6069            Low      0.08       39.89           3.04          491
# 8474   20616       Critical      0.08        2.08           1.49         3076
#
#                Customer Name       Ship Mode Customer Segment  \
# ...

# %%
plt.pie(data=r,x=r["Sales"],labels=r["Product Category"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a34b952790>,
# ...
#  [Text(1.0729871511027451, 0.2422778850172152, 'Furniture'),
#   Text(0.49633732430758654, 0.9816563861653353, 'Office Supplies'),
#   Text(-0.6723367618517891, 0.8706108652335157, 'Furniture'),
#   Text(-1.0213040546189258, 0.4085805037185969, 'Office Supplies'),
#   Text(-1.0995299181667348, 0.03215523373035272, 'Office Supplies'),
#   Text(-1.051926984551521, -0.32163584870524664, 'Office Supplies'),
#   Text(-1.0092671754621778, -0.4374697344212487, 'Office Supplies'),
#   Text(-0.9649154987312862, -0.5281458892277334, 'Office Supplies'),
#   Text(0.27660825089859986, -1.0646538759309607, 'Furniture'),
#   Text(1.0999800729253513, -0.0066211152488915076, 'Office Supplies')])

# %%
v=df["State or Province"].value_counts()
v
# Out:
# State or Province
# California              1021
# Texas                    646
# Illinois                 584
# New York                 574
# Florida                  522
# Ohio                     396
# Washington               327
# Michigan                 327
# Pennsylvania             271
# North Carolina           251
# Indiana                  241
# Minnesota                239
# Massachusetts            222
# Georgia                  214
# Virginia                 198
# Maryland                 178
# Colorado                 177
# New Jersey               177
# Wisconsin                169
# Oregon                   168
# Tennessee                166
# Missouri                 161
# Iowa                     156
# Utah                     146
# Arizona                  134
# Kansas                   133
# Maine                    128
# Alabama                  125
# Arkansas                 123
# Idaho                    114
# South Carolina           105
# ...

# %%
plt.pie(data=r,x=r["Sales"],labels=r["Customer Segment"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a351198150>,
# ...
#  [Text(1.0729871511027451, 0.2422778850172152, 'Home Office'),
#   Text(0.49633732430758654, 0.9816563861653353, 'Consumer'),
#   Text(-0.6723367618517891, 0.8706108652335157, 'Corporate'),
#   Text(-1.0213040546189258, 0.4085805037185969, 'Corporate'),
#   Text(-1.0995299181667348, 0.03215523373035272, 'Consumer'),
#   Text(-1.051926984551521, -0.32163584870524664, 'Corporate'),
#   Text(-1.0092671754621778, -0.4374697344212487, 'Corporate'),
#   Text(-0.9649154987312862, -0.5281458892277334, 'Consumer'),
#   Text(0.27660825089859986, -1.0646538759309607, 'Consumer'),
#   Text(1.0999800729253513, -0.0066211152488915076, 'Small Business')])
